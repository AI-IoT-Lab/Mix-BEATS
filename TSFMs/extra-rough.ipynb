# %%
import shutil
import os

def copy_folders(source_dir, dest_dir, folders):
    for folder in folders:
        src_folder_path = os.path.join(source_dir, folder)
        dest_folder_path = os.path.join(dest_dir, folder)

        # Check if the source folder exists
        if os.path.exists(src_folder_path):
            # Copy the folder and its contents
            shutil.copytree(src_folder_path, dest_folder_path)
            print(f"Copied {src_folder_path} to {dest_folder_path}")
        else:
            print(f"Source folder {src_folder_path} does not exist.")

# Define source and destination directories
source_directory = '../pretraining-forecasting/dataset'
destination_directory = './dataset'

# List of folders to copy
folders_to_copy = ['train', 'val', 'test']

# Call the function to copy folders
copy_folders(source_directory, destination_directory, folders_to_copy)

# %%
import numpy as np
import pandas as pd

import os
import sys
sys.path.append('./model')

import torch
from torch.utils.data import Dataset, DataLoader
from model.nbeats_ttm import NBeatsNet
from torch.utils.data import ConcatDataset

from tqdm import tqdm
# from sklearn.metrics import mean_squared_error



# metrics used for evaluation
def cal_cvrmse(pred, true, eps=1e-8):
    pred = np.array(pred)
    true = np.array(true)
    return np.power(np.square(pred - true).sum() / pred.shape[0], 0.5) / (true.sum() / pred.shape[0] + eps)

def cal_mae(pred, true):
    pred = np.array(pred)
    true = np.array(true)
    return np.mean(np.abs(pred - true))

def cal_nrmse(pred, true, eps=1e-8):
    true = np.array(true)
    pred = np.array(pred)

    M = len(true) // 24
    y_bar = np.mean(true)
    NRMSE = 100 * (1/ (y_bar+eps)) * np.sqrt((1 / (24 * M)) * np.sum((true - pred) ** 2))
    return NRMSE








def standardize_series(series, eps=1e-8):
    mean = np.mean(series)
    std = np.std(series)
    standardized_series = (series - mean) / (std+eps)
    return standardized_series, mean, std

def unscale_predictions(predictions, mean, std, eps=1e-8):
    return predictions * (std+eps) + mean


class TimeSeriesDataset(Dataset):
    def __init__(self, data, backcast_length, forecast_length, stride=1):
        # Standardize the time series data
        self.data, self.mean, self.std = standardize_series(data)
        self.backcast_length = backcast_length
        self.forecast_length = forecast_length
        self.stride = stride

    def __len__(self):
        return (len(self.data) - self.backcast_length - self.forecast_length) // self.stride + 1

    def __getitem__(self, index):
        start_index = index * self.stride
        x = self.data[start_index : start_index + self.backcast_length]
        y = self.data[start_index + self.backcast_length : start_index + self.backcast_length + self.forecast_length]
        return torch.tensor(x, dtype=torch.float32), torch.tensor(y, dtype=torch.float32)



def test(model, criterion, device, folder_path, result_path):


    median_res = []  
    for region in os.listdir(folder_path):

        region_path = os.path.join(folder_path, region)

        results_path = os.path.join(result_path, region)
        os.makedirs(results_path, exist_ok=True)

        res = []

        for building in os.listdir(region_path):

            building_id = building.rsplit(".csv",1)[0]

            if building.endswith('.csv'):
                file_path = os.path.join(region_path, building)
                df = pd.read_csv(file_path)
                energy_data = df['energy'].values
                dataset = TimeSeriesDataset(energy_data, backcast_length, forecast_length, stride)
                
                # test phase
                model.eval()
                val_losses = []
                y_true_test = []
                y_pred_test = []

                # test loop
                for x_test, y_test in DataLoader(dataset, batch_size=1):
                    x_test, y_test = x_test.to(device), y_test.to(device)
                    with torch.no_grad():
                        backcast, forecast = model(x_test)
                        loss = criterion(forecast, y_test)
                        val_losses.append(loss.item())
                        
                        # Collect true and predicted values for RMSE calculation
                        y_true_test.extend(y_test.cpu().numpy())
                        y_pred_test.extend(forecast.cpu().numpy())
                        
                # Calculate average validation loss and RMSE
                y_true_combine = np.concatenate(y_true_test, axis=0)
                y_pred_combine = np.concatenate(y_pred_test, axis=0)
                avg_test_loss = np.mean(val_losses)
                
                y_pred_combine_unscaled = unscale_predictions(y_pred_combine, dataset.mean, dataset.std)
                y_true_combine_unscaled = unscale_predictions(y_true_combine, dataset.mean, dataset.std)
                
                # Calculate CVRMSE, NRMSE, MAE on unscaled data
                cvrmse = cal_cvrmse(y_pred_combine_unscaled, y_true_combine_unscaled)
                nrmse = cal_nrmse(y_pred_combine_unscaled, y_true_combine_unscaled)
                mae = cal_mae(y_pred_combine_unscaled, y_true_combine_unscaled)

                res.append([building_id, cvrmse, nrmse, mae, avg_test_loss])

        columns = ['building_ID', 'CVRMSE', 'NRMSE', 'MAE', 'Avg_Test_Loss']
        df = pd.DataFrame(res, columns=columns)
        df.to_csv("{}/{}.csv".format(results_path, 'result'), index=False)

        med_nrmse = df['NRMSE'].median()
        median_res.append([region, med_nrmse])

    med_columns = ['Dataset','NRMSE']
    median_df = pd.DataFrame(median_res, columns=med_columns)
    median_df.to_csv("./results/nbeats_ttm/median_buildings_results.csv", index=False)




                




if __name__ == '__main__':

    
    # Parameters
    backcast_length = 168
    forecast_length = 24
    stride = 24
    batch_size = 64

    # Load datasets

    # Create data loaders


    patch_size = 8 
    num_patches = backcast_length // patch_size

    # check device 
    device = 'cuda' if torch.cuda.is_available() else 'cpu'

    # Define N-BEATS model
    model = NBeatsNet(
        device=device,
        forecast_length=forecast_length,
        backcast_length=backcast_length,
        patch_size = patch_size, 
        num_patches = num_patches,
        hidden_dim=256
    ).to(device)

    model.load_state_dict(torch.load('./model_weights/nbeats_ttm/best_model.pth'))



    # Define loss and optimizer
    criterion = torch.nn.MSELoss()

    test_dataset_path = './dataset/test'
    result_path = './results/nbeats_ttm'

    # training the model and save best parameters
    test(model=model, criterion=criterion, device=device, folder_path=test_dataset_path, result_path=result_path)
# Out:
# /tmp/ipykernel_2361954/3088813953.py:179: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('./model_weights/nbeats_ttm/best_model.pth'))

# %%
a = np.array([[2,3,4,5]])
b = np.array([[4,5,6,7]])
li = []
li.extend(a)
li.extend(b)
li
# Out:
# [array([2, 3, 4, 5]), array([4, 5, 6, 7])]

# %%
# Concatenate the arrays along the second axis (axis=1)
final_array = np.concatenate(li, axis=0)

print(final_array.shape)  # This will print (1, 24*k)
# Out:
# (8,)

# %%
import pandas as pd
import os

def convert(input_path, output_path):

    for split in os.listdir(input_path):
        
        split_path = os.path.join(input_path, split)

        for places in os.listdir(split_path):
            
            place_path = os.path.join(split_path, places)

            for building in os.listdir(place_path):

                building_name = building[:-4]
                
                des_path = os.path.join(output_path, split, places)
                os.makedirs(des_path, exist_ok=True)


                file_name = '{}.parquet'.format(building_name)
                # Define the input and output file paths
                csv_file_path = os.path.join(place_path, building)
                parquet_file_path = os.path.join(des_path, file_name)

                # Read the CSV file
                df = pd.read_csv(csv_file_path)

                # Write to Parquet format
                df.to_parquet(parquet_file_path, engine='pyarrow', index=False)

                print(f"File converted successfully: {parquet_file_path}")



input_path = '../../mixBEATS/dataset'
output_path = './parquet_dataset'
convert(input_path, output_path)
# Out:
# File converted successfully: ./parquet_dataset/test/Prayas/eMARC-1H_H134.parquet
# File converted successfully: ./parquet_dataset/test/Prayas/eMARC-1H_H010.parquet
# File converted successfully: ./parquet_dataset/test/Prayas/eMARC-1H_H042.parquet
# File converted successfully: ./parquet_dataset/test/Prayas/eMARC-1H_H057.parquet
# File converted successfully: ./parquet_dataset/test/Prayas/eMARC-1H_H004.parquet
# File converted successfully: ./parquet_dataset/test/Prayas/eMARC-1H_H052.parquet
# File converted successfully: ./parquet_dataset/test/Prayas/eMARC-1H_H084.parquet
# File converted successfully: ./parquet_dataset/test/Prayas/eMARC-1H_H122.parquet
# File converted successfully: ./parquet_dataset/test/Prayas/eMARC-1H_H066.parquet
# File converted successfully: ./parquet_dataset/test/Prayas/eMARC-1H_H019.parquet
# File converted successfully: ./parquet_dataset/test/Prayas/eMARC-1H_H091.parquet
# File converted successfully: ./parquet_dataset/test/Prayas/eMARC-1H_H069.parquet
# File converted successfully: ./parquet_dataset/test/Prayas/eMARC-1H_H037.parquet
# File converted successfully: ./parquet_dataset/test/Prayas/eMARC-1H_H125.parquet
# File converted successfully: ./parquet_dataset/test/Prayas/eMARC-1H_H089.parquet
# File converted successfully: ./parquet_dataset/test/Prayas/eMARC-1H_H099.parquet
# File converted successfully: ./parquet_dataset/test/Prayas/eMARC-1H_H018.parquet
# File converted successfully: ./parquet_dataset/test/Prayas/eMARC-1H_H136.parquet
# File converted successfully: ./parquet_dataset/test/Prayas/eMARC-1H_H115.parquet
# File converted successfully: ./parquet_dataset/test/Prayas/eMARC-1H_H043.parquet
# File converted successfully: ./parquet_dataset/test/Prayas/eMARC-1H_H090.parquet
# File converted successfully: ./parquet_dataset/test/Prayas/eMARC-1H_H032.parquet
# File converted successfully: ./parquet_dataset/test/Prayas/eMARC-1H_H133.parquet
# File converted successfully: ./parquet_dataset/test/Prayas/eMARC-1H_H137.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp23782.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp4536.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp8543.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp17568.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp11456.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp19133.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp9818.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp3719.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp5202.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp21269.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp20750.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp17356.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp10292.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp16262.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp4325.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp17457.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp15569.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp20955.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp7035.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp13490.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp19405.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp13481.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp21367.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp5497.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp8396.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp3215.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp18310.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp20381.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp10891.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp6622.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp15833.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp22768.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp8041.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp2538.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp9201.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp4387.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp7981.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp16537.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp18825.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp18466.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp14379.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp10983.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp17404.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp16787.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp11113.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp7617.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp20833.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp20771.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp24212.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp10636.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp24856.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp22253.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp18341.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp10596.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp17433.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp20776.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp11556.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp12427.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp3072.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp5772.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp3330.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp19326.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp25050.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp9546.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp15752.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp1318.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp18395.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp24321.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp22053.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp6937.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp14817.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp4915.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp16212.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp21734.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp11251.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp18156.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp13685.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp4604.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp362.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp20392.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp6376.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp5866.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp4191.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp5378.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp10604.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp18793.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp1020.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp19572.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp11474.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp9564.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp21148.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp5847.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp6310.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp21125.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp22821.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp23657.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp20619.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp9872.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp4194.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp22789.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp16320.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp18936.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp18898.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp4455.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp14798.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp5189.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp16058.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp4882.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp21244.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp20777.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp10169.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp19635.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp15816.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp9744.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp19784.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp22495.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp15375.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp22335.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp7010.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp23254.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp15418.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp19598.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp18951.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp8792.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp24155.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp7821.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp21753.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp9935.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp14408.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp13783.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp699.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp15591.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp879.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp5919.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp13727.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp16223.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp19554.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp15393.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp6456.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp23003.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp2462.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp12877.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp15527.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp19231.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp24181.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp14749.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp10294.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp3179.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp20540.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp23281.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp20118.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp4947.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp19237.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp2246.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp7848.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp11009.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp3360.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp12426.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp12290.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp9461.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp19335.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp21426.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp18173.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp5529.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp2960.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp13122.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp15548.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp20210.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp1610.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp615.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp18497.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp11142.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp15812.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp10176.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp6347.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp4539.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp25195.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp378.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp13631.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp13576.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp8247.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp18931.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp13139.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp24374.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp10872.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp15924.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp7415.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp15980.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp22161.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp17772.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp3541.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp3830.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp8813.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp962.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp2549.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp24692.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp14746.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp1097.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp24737.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp4813.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp14046.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp18648.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp19832.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp20977.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp20790.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp20924.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp16545.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp17567.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp9499.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp5188.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp2371.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp12077.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp1493.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp4633.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp2639.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp21100.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp15033.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp18336.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp3391.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp18609.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp3884.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp14300.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp18022.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp21351.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp6535.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp3935.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp16916.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp16191.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp7122.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp2985.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp661.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp25482.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp14726.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp4453.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp25044.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp16838.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp14997.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp11282.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp4289.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp22377.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp13564.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp7814.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp15692.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp3504.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp23996.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp18233.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp12177.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp442.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp3359.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp8982.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp23088.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp656.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp15348.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp5392.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp9606.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp9407.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp21870.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp10016.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp22272.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp25110.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp9317.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp20890.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp5221.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp11222.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp4108.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp12007.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp13728.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp15854.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp11817.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp21591.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp7690.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp12140.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp1875.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp234.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp4238.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp10520.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp24418.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp22183.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp7961.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp4259.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp21971.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp23935.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp14767.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp14057.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp21696.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp3464.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp25534.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp16736.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp5439.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp6795.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp9393.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp14214.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp1036.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp5199.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp12150.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp9187.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp20687.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp9358.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp10181.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp182.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp10180.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp4284.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp23825.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp16943.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp9692.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp10916.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp17308.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp22100.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp8497.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp3877.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp18957.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp15355.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp14362.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp17678.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp23944.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp12363.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp1914.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp21354.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp3473.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp20925.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp7461.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp3149.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp9289.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp13207.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp24224.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp12840.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp16150.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp7240.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp9962.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp5635.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp91.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp646.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp14816.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp5814.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp11529.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp13990.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp25283.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp2001.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp11959.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp790.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp19848.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp10920.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp25444.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp10541.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp12001.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp5965.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp2260.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp6830.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp14658.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp12396.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp18271.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp20879.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp16094.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp10440.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp6765.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp19330.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp5628.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp13730.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp19816.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp16760.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp23114.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp18328.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp14008.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp15531.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp8708.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp14792.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp24258.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp2485.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp18187.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp21432.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp21535.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp3940.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp24602.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp21325.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp15822.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp17914.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp1783.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp8928.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp8131.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp8397.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp8163.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp1041.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp23843.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp15229.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp5072.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp17337.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp10165.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp10996.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp9965.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp2373.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp23219.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp14989.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp9350.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp157.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp19180.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp754.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp1100.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp21670.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp6916.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp1335.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp21903.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp24890.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp15554.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp10111.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp19073.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp21238.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp19127.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp2669.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp17099.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp19107.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp3775.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp7095.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp17803.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp7066.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp2207.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp5732.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp13813.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp6224.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp19790.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp17.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp3369.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp17556.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp2649.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp15138.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp2274.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp14967.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp4335.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp23028.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp353.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp24545.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp19250.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp16458.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp18753.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp21082.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp5390.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp3420.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp9095.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp13974.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp12389.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp2240.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp20228.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp14690.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp18114.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp15496.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp11593.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp24814.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp914.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp22351.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp19124.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp21909.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp9273.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp21528.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp5298.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp22002.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp6104.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp12286.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp5453.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp18137.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp2516.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp7178.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp21154.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp12459.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp17168.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp2339.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp17126.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp617.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp23532.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp20522.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp5201.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp17299.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp8814.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp22233.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp2668.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp18968.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp17302.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp4280.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp1239.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp5438.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp3322.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp15167.parquet
# File converted successfully: ./parquet_dataset/test/GoiEner/Goiner_df_processed_sp9204.parquet
# ...
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8164539.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_10883502.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_10341518.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8682062.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_10890703.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8302212.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8283940.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8379384.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8149995.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_9207679.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8233352.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8564087.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_9754580.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8193367.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_10493731.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8195329.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_10850232.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8655465.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_10440635.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8171571.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8634061.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_10109468.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_10196724.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8741084.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8619761.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8618677.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_9723408.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_10632231.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_9848384.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8661240.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8638179.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_10208268.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8635675.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8372652.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8156649.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8637151.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_9773332.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_11170289.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8261350.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_9792052.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8423872.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8151705.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8504462.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8318754.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8191435.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_11170359.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_10413359.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8166677.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8238772.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_10174642.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_11105177.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_9615128.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_10042584.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8670624.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8185097.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_10233662.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8247906.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_11081794.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8664100.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8633979.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_10208228.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_9911200.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_10767858.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_10131250.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8541180.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8312590.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_11590452.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8179505.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8466439.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8447631.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_10084346.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8695156.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8597068.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8533992.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8989368.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8314008.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_11202836.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8255906.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8410226.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8181435.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8458083.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8520480.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_10866508.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8706766.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_10647695.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_9615102.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8688234.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8327744.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8778746.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8258504.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8410098.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_9985600.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8781198.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8629141.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_11139867.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8696804.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_10859164.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_10420343.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8638781.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8311722.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8305840.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8181703.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8447349.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8447685.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8267428.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8365708.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_10816398.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_10341486.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_9012346.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8638651.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8657215.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8155801.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8622053.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8451971.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_10692530.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8597388.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8154425.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8450059.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_11156263.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_10183520.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_10595662.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_10406821.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8657321.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8302440.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8308588.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8955478.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8447133.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8295224.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_10666965.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8363394.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8633739.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8320836.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_10677733.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_10170662.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8217099.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_9774878.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_11022466.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8688226.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8443177.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8208629.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_11094564.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_9754966.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_10767806.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_11139863.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8592766.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8212279.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8191479.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_10043128.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8467407.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8619757.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_10767832.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8781066.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_10493747.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8451301.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8656281.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8618177.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_11278040.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8304440.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_9061904.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8150331.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8183319.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8626541.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8471995.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8203947.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8730368.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_10238840.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8541160.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_9978018.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8361018.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_10184040.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_11450951.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_10909324.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_9977788.parquet
# File converted successfully: ./parquet_dataset/val/SGSC/sgsc-1H_8440651.parquet
# File converted successfully: ./parquet_dataset/val/Ireland/Ireland_residential_KW_H4.parquet
# File converted successfully: ./parquet_dataset/val/Ireland/Ireland_residential_KW_H11.parquet
# File converted successfully: ./parquet_dataset/val/Enernoc/enernoc_339.parquet
# File converted successfully: ./parquet_dataset/val/Enernoc/enernoc_8.parquet
# File converted successfully: ./parquet_dataset/val/Enernoc/enernoc_31.parquet
# File converted successfully: ./parquet_dataset/val/Enernoc/enernoc_771.parquet
# File converted successfully: ./parquet_dataset/val/Enernoc/enernoc_496.parquet
# File converted successfully: ./parquet_dataset/val/Enernoc/enernoc_454.parquet
# File converted successfully: ./parquet_dataset/val/Enernoc/enernoc_341.parquet
# File converted successfully: ./parquet_dataset/val/Enernoc/enernoc_285.parquet
# File converted successfully: ./parquet_dataset/val/Enernoc/enernoc_697.parquet
# File converted successfully: ./parquet_dataset/val/Enernoc/enernoc_654.parquet
# File converted successfully: ./parquet_dataset/val/Smart-star/Apt_2016_hour_Apt44.parquet
# File converted successfully: ./parquet_dataset/val/Smart-star/Apt_2016_hour_Apt40.parquet
# File converted successfully: ./parquet_dataset/val/Smart-star/Apt_2016_hour_Apt107.parquet
# File converted successfully: ./parquet_dataset/val/Smart-star/Apt_2016_hour_Apt57.parquet
# File converted successfully: ./parquet_dataset/val/Smart-star/Apt_2016_hour_Apt14.parquet
# File converted successfully: ./parquet_dataset/val/Smart-star/Apt_2016_hour_Apt12.parquet
# File converted successfully: ./parquet_dataset/val/Smart-star/Apt_2016_hour_Apt101.parquet
# File converted successfully: ./parquet_dataset/val/Smart-star/Apt_2016_hour_Apt79.parquet
# File converted successfully: ./parquet_dataset/val/Smart-star/Apt_2016_hour_Apt90.parquet
# File converted successfully: ./parquet_dataset/val/Smart-star/Apt_2016_hour_Apt72.parquet
# File converted successfully: ./parquet_dataset/val/Smart-star/Apt_2016_hour_Apt63.parquet

# %%
import pandas as pd

# Path to the sample parquet file
parquet_file_path = './parquet_dataset/train/Bareilly/Bareilly_2020_BR03.parquet'  # replace with actual file path

# Read the Parquet file
df = pd.read_parquet(parquet_file_path, engine='pyarrow')

# Display the first few rows
print(df.head())

# Optional: View info about the dataframe
print(df.info())
# Out:
#                   time  energy
# 0  2020-01-01 00:00:00   0.032
# 1  2020-01-01 01:00:00   0.032
# 2  2020-01-01 02:00:00   0.038
# 3  2020-01-01 03:00:00   0.032
# 4  2020-01-01 04:00:00   0.031
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    8784 non-null   object
#  1   energy  8784 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 137.4+ KB
# None
